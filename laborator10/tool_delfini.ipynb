# %%
path = "data/mici/dolphins/dolphins.gml"
resolution_value = 0.7

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

graph = nx.read_gml(path)

# %%
print(graph)
# Out:
# Graph with 62 nodes and 159 edges

# %%
pos = nx.spring_layout(graph)  # compute graph layout
plt.figure(figsize=(8, 8))  # image is 8 x 8 inches 
nx.draw_networkx_nodes(graph, pos, node_size=100)
nx.draw_networkx_edges(graph, pos, alpha=0.3)
plt.show()

# %%
from networkx.algorithms import community

communities_generator = community.louvain_communities(graph, resolution=resolution_value)
communities = [x for x in communities_generator]
print(communities)
# Out:
# [{'Fork', 'Scabs', 'Shmuddel', 'Kringel', 'Thumper', 'Whitetip', 'SN63', 'SN4', 'TR120', 'Grin', 'Oscar', 'CCL', 'TSN103', 'SN9', 'Hook', 'TR99', 'Stripes', 'Double', 'Zap', 'SN100', 'TR88'}, {'SN96', 'TR77', 'Bumper', 'Fish', 'Zipfel', 'TSN83', 'Beak'}, {'Jonah', 'Five', 'Vau', 'Cross', 'Topless', 'Patchback', 'SMN5', 'MN105', 'MN60', 'Trigger', 'Haecksel', 'MN83'}, {'Jet', 'DN21', 'SN89', 'SN90', 'Wave', 'DN63', 'Gallatin', 'Quasi', 'Zig', 'Ripplefluke', 'Upbang', 'Knit', 'Feather', 'Mus', 'TR82', 'Web', 'Beescratch', 'PL', 'MN23', 'Number1', 'DN16', 'Notch'}]

# %%
colors = plt.cm.rainbow(np.linspace(0, 1, len(communities)))

plt.figure(figsize=(8, 8))
for community, color in zip(communities, colors):
    nx.draw_networkx_nodes(graph, pos, nodelist=community, node_color=[color])

nx.draw_networkx_edges(graph, pos, alpha=0.3)

plt.show()

# %%
def get_node_label(node_id):
    return node_id

# %%
for i, community in enumerate(communities):
    print(f'{i + 1} community:', end=' ')
    for node in community:
        print(get_node_label(node), end=', ')
    print()
# Out:
# 1 community: Fork, Scabs, Shmuddel, Kringel, Thumper, Whitetip, SN63, SN4, TR120, Grin, Oscar, CCL, TSN103, SN9, Hook, TR99, Stripes, Double, Zap, SN100, TR88,
# 2 community: SN96, TR77, Bumper, Fish, Zipfel, TSN83, Beak,
# 3 community: Jonah, Five, Vau, Cross, Topless, Patchback, SMN5, MN105, MN60, Trigger, Haecksel, MN83,
# 4 community: Jet, DN21, SN89, SN90, Wave, DN63, Gallatin, Quasi, Zig, Ripplefluke, Upbang, Knit, Feather, Mus, TR82, Web, Beescratch, PL, MN23, Number1, DN16, Notch,

# %%
for index, node in enumerate(graph.nodes(data=False)):
    for i, community in enumerate(communities):
        if node in community:
            print(f'{index + 1} {i + 1}')
# Out:
# 1 2
# 2 4
# 3 2
# 4 1
# 5 3
# 6 4
# 7 4
# 8 4
# 9 1
# 10 4
# 11 2
# 12 3
# 13 1
# 14 4
# 15 1
# 16 3
# 17 1
# 18 4
# 19 3
# 20 4
# 21 1
# 22 3
# 23 4
# 24 3
# 25 3
# 26 4
# 27 4
# 28 4
# 29 1
# 30 3
# 31 4
# 32 4
# 33 4
# 34 1
# 35 1
# 36 3
# 37 1
# 38 1
# 39 1
# 40 4
# 41 1
# 42 4
# 43 2
# 44 1
# 45 1
# 46 3
# 47 1
# 48 2
# 49 4
# 50 1
# 51 1
# 52 3
# 53 1
# 54 2
# 55 4
# 56 3
# 57 4
# 58 4
# 59 1
# 60 1
# 61 4
# 62 2
