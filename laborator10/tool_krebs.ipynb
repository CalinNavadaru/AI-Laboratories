# %%
path = "data/mici/krebs/krebs.gml"
resolution_value = 0.8

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
graph = nx.read_gml(path)

# %%
print(graph)
# Out:
# Graph with 105 nodes and 441 edges

# %%
pos = nx.spring_layout(graph)  # compute graph layout
plt.figure(figsize=(8, 8))  # image is 8 x 8 inches 
nx.draw_networkx_nodes(graph, pos, node_size = 100)
nx.draw_networkx_edges(graph, pos, alpha = 0.3)
plt.show()

# %%
from networkx.algorithms import community

communities_generator = community.louvain_communities(graph, resolution=resolution_value)
communities = [x for x in communities_generator]
print(communities)
# Out:
# [{'1000 Years for Revenge', 'Ghost Wars', 'The Man Who Warned America', 'Why America Slept', 'Bush vs. the Beltway', 'Dangerous Dimplomacy', 'Sleeping With the Devil', "Charlie Wilson's War"}, {'Ten Minutes from Normal', 'Tales from the Left Coast', 'Legacy', 'Losing Bin Laden', 'The Official Handbook Vast Right Wing Conspiracy', 'The Savage Nation', 'Spin Sisters', 'The Death of Right and Wrong', 'Let Freedom Ring', 'Fighting Back', 'We Will Prevail', "Who's Looking Out for You?", 'Bush Country', 'Betrayal', 'The Third Terrorist', "Hillary's Scheme", 'The Faith of George W Bush', "Rumsfeld's War", 'Arrogance', 'Meant To Be', 'Persecution', 'The Enemy Within', 'Breakdown', 'Hating America', 'Deliver Us from Evil', 'The Right Man', 'Useful Idiots', 'Dereliction of Duty', 'Endgame', 'Shut Up and Sing', 'Why Courage Matters', 'Bias', 'Hollywood Interrupted', 'The Real America', 'Give Me a Break', 'Those Who Trespass', "The O'Reilly Factor", 'Off with Their Heads', 'Slander', 'The Perfect Wife', 'A National Party No More', 'The French Betrayal of America', 'The Bushes'}, {'The Future of Freedom', 'Disarming Iraq', 'Rogue Nation', 'Things Worth Fighting For', 'Allies', 'America Unbound', 'Colossus', 'Rise of the Vulcans', 'Empire', 'Surprise, Security, the American Experience', 'The Choice', 'Soft Power'}, {'What Liberal Media?', "MoveOn's 50 Ways to Love Your Country", 'The Politics of Truth', 'Had Enough?', 'Thieves in High Places', 'The Great Unraveling', "We're Right They're Wrong", 'The New Pearl Harbor', 'Against All Enemies', 'Power Plays', 'The Lies of George W. Bush', 'House of Bush, House of Saud', 'The Culture of Fear', 'Stupid White Men', 'The Best Democracy Money Can Buy', 'The Buying of the President 2004', 'Buck Up Suck Up', 'Hegemony or Survival', 'Fanatics and Fools', "Dude, Where's My Country?", 'The Exception to the Rulers', "It's Still the Economy, Stupid!", 'American Dynasty', 'Worse Than Watergate', 'Lies and the Lying Liars Who Tell Them', 'Perfectly Legal', 'Bushwomen', 'Bush at War', 'The Clinton Wars', "All the Shah's Men", 'Rush Limbaugh Is a Big Fat Idiot', 'The Bubble of American Supremacy', 'Weapons of Mass Deception', 'Big Lies', 'Plan of Attack', 'Living History', 'Shrub', 'The Price of Loyalty', 'Freethinkers', 'The Sorrows of Empire', 'Bushwhacked', 'Downsize This!'}]

# %%
colors = plt.cm.rainbow(np.linspace(0, 1, len(communities)))

plt.figure(figsize=(8, 8))
for community, color in zip(communities, colors):
    nx.draw_networkx_nodes(graph, pos, nodelist=community, node_color=[color])

nx.draw_networkx_edges(graph, pos, alpha=0.3)

plt.show()

# %%
def get_node_label(node_id):
    return node_id

# %%
for i, community in enumerate(communities):
    print(f'{i + 1} community:', end=' ')
    for node in community:
        print(get_node_label(node), end=', ')
    print()
# Out:
# 1 community: 1000 Years for Revenge, Ghost Wars, The Man Who Warned America, Why America Slept, Bush vs. the Beltway, Dangerous Dimplomacy, Sleeping With the Devil, Charlie Wilson's War,
# 2 community: Ten Minutes from Normal, Tales from the Left Coast, Legacy, Losing Bin Laden, The Official Handbook Vast Right Wing Conspiracy, The Savage Nation, Spin Sisters, The Death of Right and Wrong, Let Freedom Ring, Fighting Back, We Will Prevail, Who's Looking Out for You?, Bush Country, Betrayal, The Third Terrorist, Hillary's Scheme, The Faith of George W Bush, Rumsfeld's War, Arrogance, Meant To Be, Persecution, The Enemy Within, Breakdown, Hating America, Deliver Us from Evil, The Right Man, Useful Idiots, Dereliction of Duty, Endgame, Shut Up and Sing, Why Courage Matters, Bias, Hollywood Interrupted, The Real America, Give Me a Break, Those Who Trespass, The O'Reilly Factor, Off with Their Heads, Slander, The Perfect Wife, A National Party No More, The French Betrayal of America, The Bushes,
# 3 community: The Future of Freedom, Disarming Iraq, Rogue Nation, Things Worth Fighting For, Allies, America Unbound, Colossus, Rise of the Vulcans, Empire, Surprise, Security, the American Experience, The Choice, Soft Power,
# 4 community: What Liberal Media?, MoveOn's 50 Ways to Love Your Country, The Politics of Truth, Had Enough?, Thieves in High Places, The Great Unraveling, We're Right They're Wrong, The New Pearl Harbor, Against All Enemies, Power Plays, The Lies of George W. Bush, House of Bush, House of Saud, The Culture of Fear, Stupid White Men, The Best Democracy Money Can Buy, The Buying of the President 2004, Buck Up Suck Up, Hegemony or Survival, Fanatics and Fools, Dude, Where's My Country?, The Exception to the Rulers, It's Still the Economy, Stupid!, American Dynasty, Worse Than Watergate, Lies and the Lying Liars Who Tell Them, Perfectly Legal, Bushwomen, Bush at War, The Clinton Wars, All the Shah's Men, Rush Limbaugh Is a Big Fat Idiot, The Bubble of American Supremacy, Weapons of Mass Deception, Big Lies, Plan of Attack, Living History, Shrub, The Price of Loyalty, Freethinkers, The Sorrows of Empire, Bushwhacked, Downsize This!,

# %%
for index, node in enumerate(graph.nodes(data=False)):
    for i, community in enumerate(communities):
        if node in community:
            print(f'{index + 1} {i + 1}')
# Out:
# 1 1
# 2 1
# 3 1
# 4 2
# 5 1
# 6 1
# 7 1
# 8 1
# 9 2
# 10 2
# 11 2
# 12 2
# 13 2
# 14 2
# 15 2
# 16 2
# 17 2
# 18 2
# 19 2
# 20 2
# 21 2
# 22 2
# 23 2
# 24 2
# 25 2
# 26 2
# 27 2
# 28 2
# 29 4
# 30 1
# 31 4
# 32 4
# 33 2
# 34 2
# 35 2
# 36 2
# 37 2
# 38 2
# 39 2
# 40 2
# 41 2
# 42 2
# 43 2
# 44 2
# 45 2
# 46 2
# 47 4
# 48 2
# 49 2
# 50 2
# 51 3
# 52 3
# 53 3
# 54 2
# 55 2
# 56 2
# 57 2
# 58 2
# 59 3
# 60 4
# 61 4
# 62 4
# 63 4
# 64 4
# 65 3
# 66 3
# 67 4
# 68 3
# 69 3
# 70 3
# 71 4
# 72 4
# 73 4
# 74 4
# 75 4
# 76 4
# 77 4
# 78 4
# 79 4
# 80 4
# 81 4
# 82 4
# 83 4
# 84 4
# 85 4
# 86 3
# 87 4
# 88 4
# 89 4
# 90 4
# 91 4
# 92 4
# 93 4
# 94 4
# 95 4
# 96 4
# 97 4
# 98 4
# 99 4
# 100 4
# 101 4
# 102 4
# 103 4
# 104 3
# 105 3
