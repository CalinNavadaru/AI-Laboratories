# %%
path = "data/mici/football/football.gml"
resolution_value = 1.7

# %%
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np
graph = nx.read_gml(path)

# %%
print(graph)
# Out:
# Graph with 115 nodes and 613 edges

# %%
pos = nx.spring_layout(graph)  # compute graph layout
plt.figure(figsize=(8, 8))  # image is 8 x 8 inches 
nx.draw_networkx_nodes(graph, pos, node_size = 100)
nx.draw_networkx_edges(graph, pos, alpha = 0.3)
plt.show()

# %%
from networkx.algorithms import community

communities_generator = community.louvain_communities(graph, resolution=resolution_value)
communities = [x for x in communities_generator]
print(communities)
# Out:
# [{'Stanford', 'SouthernCalifornia', 'California', 'Arizona', 'OregonState', 'Oregon', 'WashingtonState', 'Washington', 'UCLA', 'ArizonaState'}, {'Nebraska', 'TexasTech', 'Oklahoma', 'IowaState', 'KansasState', 'Texas', 'Missouri', 'Baylor', 'OklahomaState', 'TexasA&M', 'Kansas', 'Colorado'}, {'Michigan', 'Indiana', 'PennState', 'Wisconsin', 'MichiganState', 'OhioState', 'Minnesota', 'Illinois', 'Iowa', 'Purdue', 'Northwestern'}, {'BoiseState', 'Idaho', 'UtahState', 'NorthTexas', 'ArkansasState', 'NewMexicoState'}, {'FloridaState', 'NorthCarolina', 'Duke', 'WakeForest', 'Virginia', 'Maryland', 'Clemson', 'GeorgiaTech', 'NorthCarolinaState'}, {'Nevada', 'Tulsa', 'FresnoState', 'TexasElPaso', 'Rice', 'TexasChristian', 'SouthernMethodist', 'SanJoseState', 'Hawaii'}, {'NorthernIllinois', 'Ohio', 'Buffalo', 'Marshall', 'Akron', 'EasternMichigan', 'CentralMichigan', 'BowlingGreenState', 'BallState', 'CentralFlorida', 'MiamiOhio', 'Kent', 'Connecticut', 'WesternMichigan', 'Toledo'}, {'MississippiState', 'LouisianaLafayette', 'Arkansas', 'SouthCarolina', 'Georgia', 'Alabama', 'LouisianaMonroe', 'Mississippi', 'MiddleTennesseeState', 'Vanderbilt', 'Kentucky', 'LouisianaState', 'LouisianaTech', 'Florida', 'Tennessee', 'Auburn'}, {'Memphis', 'Cincinnati', 'AlabamaBirmingham', 'Army', 'Tulane', 'Louisville', 'Houston', 'EastCarolina', 'SouthernMississippi'}, {'NevadaLasVegas', 'Wyoming', 'NewMexico', 'SanDiegoState', 'BrighamYoung', 'AirForce', 'ColoradoState', 'Utah'}, {'Pittsburgh', 'Syracuse', 'WestVirginia', 'Temple', 'VirginiaTech', 'MiamiFlorida', 'Rutgers', 'Navy', 'NotreDame', 'BostonCollege'}]

# %%
colors = plt.cm.rainbow(np.linspace(0, 1, len(communities)))

plt.figure(figsize=(8, 8))
for community, color in zip(communities, colors):
    nx.draw_networkx_nodes(graph, pos, nodelist=community, node_color=[color])

nx.draw_networkx_edges(graph, pos, alpha=0.3)

plt.show()

# %%
def get_node_label(node_id):
    return node_id

# %%
for i, community in enumerate(communities):
    print(f'{i + 1} community:', end=' ')
    for node in community:
        print(get_node_label(node), end=', ')
    print()
# Out:
# 1 community: Stanford, SouthernCalifornia, California, Arizona, OregonState, Oregon, WashingtonState, Washington, UCLA, ArizonaState,
# 2 community: Nebraska, TexasTech, Oklahoma, IowaState, KansasState, Texas, Missouri, Baylor, OklahomaState, TexasA&M, Kansas, Colorado,
# 3 community: Michigan, Indiana, PennState, Wisconsin, MichiganState, OhioState, Minnesota, Illinois, Iowa, Purdue, Northwestern,
# 4 community: BoiseState, Idaho, UtahState, NorthTexas, ArkansasState, NewMexicoState,
# 5 community: FloridaState, NorthCarolina, Duke, WakeForest, Virginia, Maryland, Clemson, GeorgiaTech, NorthCarolinaState,
# 6 community: Nevada, Tulsa, FresnoState, TexasElPaso, Rice, TexasChristian, SouthernMethodist, SanJoseState, Hawaii,
# 7 community: NorthernIllinois, Ohio, Buffalo, Marshall, Akron, EasternMichigan, CentralMichigan, BowlingGreenState, BallState, CentralFlorida, MiamiOhio, Kent, Connecticut, WesternMichigan, Toledo,
# 8 community: MississippiState, LouisianaLafayette, Arkansas, SouthCarolina, Georgia, Alabama, LouisianaMonroe, Mississippi, MiddleTennesseeState, Vanderbilt, Kentucky, LouisianaState, LouisianaTech, Florida, Tennessee, Auburn,
# 9 community: Memphis, Cincinnati, AlabamaBirmingham, Army, Tulane, Louisville, Houston, EastCarolina, SouthernMississippi,
# 10 community: NevadaLasVegas, Wyoming, NewMexico, SanDiegoState, BrighamYoung, AirForce, ColoradoState, Utah,
# 11 community: Pittsburgh, Syracuse, WestVirginia, Temple, VirginiaTech, MiamiFlorida, Rutgers, Navy, NotreDame, BostonCollege,

# %%
for index, node in enumerate(graph.nodes(data=False)):
    for i, community in enumerate(communities):
        if node in community:
            print(f'{index + 1} {i + 1}')
# Out:
# 1 10
# 2 5
# 3 3
# 4 2
# 5 10
# 6 2
# 7 3
# 8 1
# 9 1
# 10 10
# 11 2
# 12 4
# 13 7
# 14 3
# 15 7
# 16 3
# 17 10
# 18 8
# 19 7
# 20 11
# 21 8
# 22 1
# 23 1
# 24 10
# 25 4
# 26 5
# 27 7
# 28 8
# 29 4
# 30 11
# 31 11
# 32 7
# 33 3
# 34 5
# 35 7
# 36 11
# 37 7
# 38 5
# 39 7
# 40 3
# 41 2
# 42 10
# 43 7
# 44 7
# 45 9
# 46 5
# 47 6
# 48 3
# 49 9
# 50 6
# 51 4
# 52 1
# 53 2
# 54 6
# 55 7
# 56 11
# 57 8
# 58 9
# 59 8
# 60 8
# 61 3
# 62 7
# 63 8
# 64 8
# 65 3
# 66 8
# 67 9
# 68 6
# 69 1
# 70 4
# 71 8
# 72 7
# 73 2
# 74 6
# 75 2
# 76 9
# 77 8
# 78 1
# 79 1
# 80 11
# 81 11
# 82 2
# 83 11
# 84 6
# 85 2
# 86 7
# 87 9
# 88 8
# 89 6
# 90 5
# 91 4
# 92 9
# 93 9
# 94 10
# 95 11
# 96 8
# 97 8
# 98 8
# 99 2
# 100 7
# 101 3
# 102 11
# 103 2
# 104 5
# 105 10
# 106 5
# 107 3
# 108 2
# 109 1
# 110 5
# 111 6
# 112 1
# 113 9
# 114 8
# 115 6
